# %% [markdown]
# <a href="https://colab.research.google.com/github/2312019/Prodigy_DS_2/blob/main/Prodigy_DS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 🔹 Load Dataset
df = pd.read_csv('/content/gender_submission.csv')

# 🔹 Show Data
print("First 5 Rows:")
print(df.head())
# Out:
# First 5 Rows:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
# 🔹 Data Info
print("\nData Info:")
print(df.info())
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
# dtypes: int64(2)
# memory usage: 6.7 KB
# None

# %%
# 🔹 Missing Values
print("\nMissing Values:")
print(df.isnull().sum())

# 🔹 DATA CLEANING
# Note: gender_submission.csv typically only has PassengerId and Survived.
# The following cleaning steps are commented out as they rely on columns not present in gender_submission.csv.

# Fill missing values (commented out as 'Age' and 'Embarked' are not in gender_submission.csv)
# df['Age'].fillna(df['Age'].mean(), inplace=True)
# df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# Drop unnecessary column (commented out as 'Cabin' is not in gender_submission.csv)
# if 'Cabin' in df.columns:
#     df.drop(['Cabin'], axis=1, inplace=True)

# Check again
print("\nAfter Cleaning Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# PassengerId    0
# Survived       0
# dtype: int64
#
# After Cleaning Missing Values:
# PassengerId    0
# Survived       0
# dtype: int64

# %%
# 🔹 EDA (EXPLORATORY DATA ANALYSIS)
# Note: Most EDA plots are commented out as they rely on columns not present in gender_submission.csv.

# 1. Survival Count
plt.figure()
sns.countplot(x='Survived', data=df)
plt.title("Survival Count")
plt.show()

# 2. Survival by Gender (commented out as 'Sex' is not in gender_submission.csv)
# plt.figure()
# sns.countplot(x='Sex', hue='Survived', data=df)
# plt.title("Survival by Gender")
# plt.show()

# 3. Age Distribution (commented out as 'Age' is not in gender_submission.csv)
# plt.figure()
# plt.hist(df['Age'], bins=20)
# plt.title("Age Distribution")
# plt.xlabel("Age")
# plt.ylabel("Frequency")
# plt.show()

# 4. Passenger Class vs Survival (commented out as 'Pclass' is not in gender_submission.csv)
# plt.figure()
# sns.countplot(x='Pclass', hue='Survived', data=df)
# plt.title("Class vs Survival")
# plt.show()

# %%
# 🔹 SUMMARY
print("\nInsights:")
print("Based on the available data (gender_submission.csv, which only contains PassengerId and Survived):")
print("1. The count of survivors (1) vs non-survivors (0) can be observed from the Survival Count plot.")
print("Note: Insights related to gender, age, or passenger class are not derivable from this specific dataset.")
# print("1. Females have higher survival rate") # Commented out
# print("2. 1st class passengers survived more") # Commented out
# print("3. Most passengers are between age 20–40") # Commented out
# Out:
# Insights:
# Based on the available data (gender_submission.csv, which only contains PassengerId and Survived):
# 1. The count of survivors (1) vs non-survivors (0) can be observed from the Survival Count plot.
# Note: Insights related to gender, age, or passenger class are not derivable from this specific dataset.

# %%
df = pd.read_csv('/content/gender_submission.csv')
display(df.head())
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1
